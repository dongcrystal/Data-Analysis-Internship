# %% [markdown]
# <a href="https://colab.research.google.com/github/dongcrystal/Data-Analysis-Internship/blob/main/Popular_tourist_destinations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
road_file = files.upload()
# Out:
#      <input type="file" id="files-db4feb0f-fc92-4fcf-b93f-e1a398607c83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db4feb0f-fc92-4fcf-b93f-e1a398607c83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
import pandas as pd

# %%
data = pd.read_csv(io.BytesIO(road_file['Popular tourist destinations_total.csv']))
data.head()
# Out:
#    순위       관광지명                    주소           분류    검색 수
# 0   1     제주국제공항        제주 제주시 공항로 2-0         교통시설  782062
# 1   2     동문재래시장    제주 제주시 관덕로14길 20-0           시장  273399
# 2   3  서귀포매일올레시장  제주 서귀포시 중앙로62번길 18-0           시장  249456
# 3   4     함덕해수욕장    제주 제주시 조함해안로 525-0  자연경관(하천/해양)  185410
# 4   5      성산일출봉    제주 서귀포시 일출로 284-12      자연경관(산)  182137

# %%
data.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
data.values
# Out:
# array([[1, '제주국제공항', '제주 제주시 공항로 2-0', '교통시설', 782062],
#        [2, '동문재래시장', '제주 제주시 관덕로14길 20-0', '시장', 273399],
#        [3, '서귀포매일올레시장', '제주 서귀포시 중앙로62번길 18-0', '시장', 249456],
#        [4, '함덕해수욕장', '제주 제주시 조함해안로 525-0', '자연경관(하천/해양)', 185410],
#        [5, '성산일출봉', '제주 서귀포시 일출로 284-12', '자연경관(산)', 182137],
#        [6, '협재해수욕장', '제주 제주시', '자연경관(하천/해양)', 170059],
#        [7, '이마트서귀포점', '제주 서귀포시 일주동로 9209-0', '대형마트', 103476],
#        [8, '곽지해수욕장', '제주 제주시', '자연경관(하천/해양)', 102154],
#        [9, '섭지코지', '제주 서귀포시 섭지코지로 107-0', '기타관광', 101898],
#        [10, '아르떼뮤지엄제주', '제주 제주시 어림비로 478-0', '전시시설', 100282],
#        [11, '아쿠아플라넷제주', '제주 서귀포시 섭지코지로 93-15', '테마공원', 100026],
#        [12, '오설록티뮤지엄', '제주 서귀포시 신화역사로 15-0', '전시시설', 97744],
#        [13, '한라산둘레길사려니숲길', '제주 제주시', '기타레저스포츠', 89486],
#        [14, '스누피가든', '제주 제주시 금백조로 930-0', '기타관광', 88685],
#        [15, '비자림', '제주 제주시 비자숲길 55-0', '자연공원', 87520],
#        [16, '그랜드하얏트제주', '제주 제주시 노연로 12-0', '호텔', 79574],
# ...

# %%
data.describe()
# Out:
#                순위           검색 수
# count  100.000000     100.000000
# mean    50.500000   64504.580000
# std     29.011492   83991.779498
# min      1.000000   22216.000000
# 25%     25.750000   32004.000000
# 50%     50.500000   45339.500000
# 75%     75.250000   66773.000000
# max    100.000000  782062.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure
plt.plot([1000, 5000])

# %%
data2 = data.copy()

# %%
data2.head()
# Out:
#    순위       관광지명                    주소           분류    검색 수
# 0   1     제주국제공항        제주 제주시 공항로 2-0         교통시설  782062
# 1   2     동문재래시장    제주 제주시 관덕로14길 20-0           시장  273399
# 2   3  서귀포매일올레시장  제주 서귀포시 중앙로62번길 18-0           시장  249456
# 3   4     함덕해수욕장    제주 제주시 조함해안로 525-0  자연경관(하천/해양)  185410
# 4   5      성산일출봉    제주 서귀포시 일출로 284-12      자연경관(산)  182137

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

data['검색 수'].plot(kind='barh',grid=True,figsize=(10.5))
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e8b5e3079b97> in <cell line: 4>()
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3
# ----> 4 data['검색 수'].plot(kind='barh',grid=True,figsize=(10.5))
#       5 plt.show
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
#check data types
data.dtypes
# Out:
# 순위       int64
# 관광지명    object
# 주소      object
# 분류      object
# 검색 수     int64
# dtype: object

# %%
data.set_index('관광지명', inplace=True)

# %%
data.head()
# Out:
#            순위                    주소           분류    검색 수
# 관광지명
# 제주국제공항      1        제주 제주시 공항로 2-0         교통시설  782062
# 동문재래시장      2    제주 제주시 관덕로14길 20-0           시장  273399
# 서귀포매일올레시장   3  제주 서귀포시 중앙로62번길 18-0           시장  249456
# 함덕해수욕장      4    제주 제주시 조함해안로 525-0  자연경관(하천/해양)  185410
# 성산일출봉       5    제주 서귀포시 일출로 284-12      자연경관(산)  182137

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

data['검색 수'].plot(kind='barh',grid=True,figsize=(10.5))
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-e8b5e3079b97> in <cell line: 4>()
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3
# ----> 4 data['검색 수'].plot(kind='barh',grid=True,figsize=(10.5))
#       5 plt.show
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
data2 = data.copy()

# %%
data2 = data2.drop(['순위','주소', '분류'], axis = 1)

# %%
data2.head()
# Out:
#              검색 수
# 관광지명
# 제주국제공항     782062
# 동문재래시장     273399
# 서귀포매일올레시장  249456
# 함덕해수욕장     185410
# 성산일출봉      182137

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(5)
years = ['제주국제공항', '동문재래시장', '서귀포매일올레시장','함덕해수욕장','성산일출봉']
values = [782062, 273399, 249456, 185410, 182137]

plt.bar(x, values)
plt.xticks(x, years)

plt.show()

# %%
# importing packages

import numpy as np

import pandas as pd



import matplotlib.pyplot as plt

import seaborn as sns

plt.rcParams['figure.figsize'] = [10, 6]

# %%
data2.shape
(244, 7)


data2.head()
# Out:
#              검색 수
# 관광지명
# 제주국제공항     782062
# 동문재래시장     273399
# 서귀포매일올레시장  249456
# 함덕해수욕장     185410
# 성산일출봉      182137

# %%
data2['검색 수'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
new_df = data2.drop(10, axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-5ea47af44183> in <cell line: 1>()
# ----> 1 new_df = data2.drop(10, axis=0)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

emp = pd.read_csv("Popular tourist destinations_total.csv")
result = emp.groupby('관광지명')['검색 수'].mean().reset_index()
result.plot.bar(x='관광지명', figsize = (8, 5))
# Out:
# <Axes: xlabel='관광지명'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44285 (\N{HANGUL SYLLABLE GWAG}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   func(*args, **kwargs)
# ...
