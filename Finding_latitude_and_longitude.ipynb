# %%
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files
road_file = files.upload()
# Out:
#      <input type="file" id="files-679f6db5-f1a0-46e3-bccd-9efb08ab7d3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-679f6db5-f1a0-46e3-bccd-9efb08ab7d3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
dataset = pd.read_csv(io.BytesIO(road_file['서귀포 위도경도.csv']))

# %%
dataset.head()
# Out:
#     순위          관광지명                                   주소  \
# 0  NaN  StringFilter  MapsTooltip - Hidden - StringFilter
# 1  1.0     서귀포매일올레시장                 제주 서귀포시 중앙로62번길 18-0
# 2  2.0         성산일출봉                   제주 서귀포시 일출로 284-12
# 3  3.0       오설록티뮤지엄                   제주 서귀포시 신화역사로 15-0
# 4  4.0          섭지코지                  제주 서귀포시 섭지코지로 107-0
#
#                       Latitude                     Longitude         분류  \
# 0  MapsLat - Hidden - NoFilter  MapsLong - Hidden - NoFilter  CSVFilter
# 1                   33.2501737                   126.5634281         시장
# 2                   33.4621008                   126.9362017    자연경관(산)
# 3                     33.30601                   126.2901309       전시시설
# 4                   33.4300919                   126.9272996       기타관광
#
#     외지인 검색 수
# 0        NaN
# 1  1054841.0
# 2   770605.0
# 3   512196.0
# 4   488655.0

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
dataset.values
# Out:
# array([[1, '서귀포매일올레시장', '제주 서귀포시 중앙로62번길 18-0', '시장', 1054841],
#        [2, '성산일출봉', '제주 서귀포시 일출로 284-12', '자연경관(산)', 770605],
#        [3, '오설록티뮤지엄', '제주 서귀포시 신화역사로 15-0', '전시시설', 512196],
#        [4, '섭지코지', '제주 서귀포시 섭지코지로 107-0', '기타관광', 488655],
#        [5, '천지연폭포', '제주 서귀포시 서문서로 1-1', '자연경관(산)', 368314],
#        [6, '카멜리아힐', '제주 서귀포시 병악로 166-0', '테마공원', 349017],
#        [7, '아쿠아플라넷제주', '제주 서귀포시 섭지코지로 93-15', '테마공원', 348601],
#        [8, '쇠소깍', '제주 서귀포시 쇠소깍로 128-0', '기타관광', 338054],
#        [9, '이마트서귀포점', '제주 서귀포시 일주동로 9209-0', '대형마트', 333223],
#        [10, '주상절리대', '제주 서귀포시 이어도로 36-30', '기타관광', 326730],
#        [11, '용머리해안', '제주 서귀포시 사계남로216번길 24-32', '기타관광', 278793],
#        [12, '신라호텔제주', '제주 서귀포시 중문관광로72번길 75-0', '호텔', 272191],
#        [13, '정방폭포', '제주 서귀포시 칠십리로214번길 37', '자연경관(산)', 243411],
#        [14, '성산포종합여객터미널', '제주 서귀포시 성산등용로 130-21', '교통시설', 229541],
#        [15, '성산항', '제주 서귀포시 성산읍 성산등용로 129-21', '자연경관(하천/해양)', 227037],
# ...

# %%
dataset.values[:15]
# Out:
# array([[1, '서귀포매일올레시장', '제주 서귀포시 중앙로62번길 18-0', '시장', 1054841],
#        [2, '성산일출봉', '제주 서귀포시 일출로 284-12', '자연경관(산)', 770605],
#        [3, '오설록티뮤지엄', '제주 서귀포시 신화역사로 15-0', '전시시설', 512196],
#        [4, '섭지코지', '제주 서귀포시 섭지코지로 107-0', '기타관광', 488655],
#        [5, '천지연폭포', '제주 서귀포시 서문서로 1-1', '자연경관(산)', 368314],
#        [6, '카멜리아힐', '제주 서귀포시 병악로 166-0', '테마공원', 349017],
#        [7, '아쿠아플라넷제주', '제주 서귀포시 섭지코지로 93-15', '테마공원', 348601],
#        [8, '쇠소깍', '제주 서귀포시 쇠소깍로 128-0', '기타관광', 338054],
#        [9, '이마트서귀포점', '제주 서귀포시 일주동로 9209-0', '대형마트', 333223],
#        [10, '주상절리대', '제주 서귀포시 이어도로 36-30', '기타관광', 326730],
#        [11, '용머리해안', '제주 서귀포시 사계남로216번길 24-32', '기타관광', 278793],
#        [12, '신라호텔제주', '제주 서귀포시 중문관광로72번길 75-0', '호텔', 272191],
#        [13, '정방폭포', '제주 서귀포시', '자연경관(산)', 243411],
#        [14, '성산포종합여객터미널', '제주 서귀포시 성산등용로 130-21', '교통시설', 229541],
#        [15, '성산항', '제주 서귀포시', '자연경관(하천/해양)', 227037]], dtype=object)

# %%
address= dataset['주소']
print(address.head())
# Out:
# 0    제주 서귀포시 중앙로62번길 18-0
# 1      제주 서귀포시 일출로 284-12
# 2      제주 서귀포시 신화역사로 15-0
# 3     제주 서귀포시 섭지코지로 107-0
# 4        제주 서귀포시 서문서로 1-1
# Name: 주소, dtype: object

# %%
for i in range(len(address)):
    a = address[i].split(' ')
    address[i] = " ".join(a[0:4])
print(address)
# Out:
# 0     제주 서귀포시 중앙로62번길 18-0
# 1       제주 서귀포시 일출로 284-12
# 2       제주 서귀포시 신화역사로 15-0
# 3      제주 서귀포시 섭지코지로 107-0
# 4         제주 서귀포시 서문서로 1-1
#               ...
# 95     제주 서귀포시 일주서로 1611-0
# 96     제주 서귀포시 민속해안로 537-0
# 97       제주 서귀포시 남성중로 40-0
# 98    제주 서귀포시 중산간서로 1878-0
# 99       제주 서귀포시 토평동 산15-1
# Name: 주소, Length: 100, dtype: object
# <ipython-input-24-2edbd2da39d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   address[i] = " ".join(a[0:4])

# %%
pip install geopy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
#####주소를 위,경도 값으로 변환하기 #####
latitude = []
longitude =[]

for i in address:
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])

# %%
#####Dataframe만들기######
address_df = pd.DataFrame({'관광지명': dataset['관광지명'],'상세주소':dataset['주소'],'주소':address,'위도':latitude,'경도':longitude})

#df저장
#address_df.to_csv('jungu_incheon_coffeeshop.csv')

# %%
address_df
# Out:
#          관광지명                  상세주소                    주소         위도  \
# 0   서귀포매일올레시장  제주 서귀포시 중앙로62번길 18-0  제주 서귀포시 중앙로62번길 18-0  33.252680
# 1       성산일출봉    제주 서귀포시 일출로 284-12    제주 서귀포시 일출로 284-12  33.462147
# 2     오설록티뮤지엄    제주 서귀포시 신화역사로 15-0    제주 서귀포시 신화역사로 15-0  33.310436
# 3        섭지코지   제주 서귀포시 섭지코지로 107-0   제주 서귀포시 섭지코지로 107-0  33.438281
# 4       천지연폭포      제주 서귀포시 서문서로 1-1      제주 서귀포시 서문서로 1-1  33.247905
# ..        ...                   ...                   ...        ...
# 95    건강과성박물관   제주 서귀포시 일주서로 1611-0   제주 서귀포시 일주서로 1611-0   0.000000
# 96     해비치리조트   제주 서귀포시 민속해안로 537-0   제주 서귀포시 민속해안로 537-0   0.000000
# 97     서귀포잠수함     제주 서귀포시 남성중로 40-0     제주 서귀포시 남성중로 40-0  33.241893
# 98    소인국테마파크  제주 서귀포시 중산간서로 1878-0  제주 서귀포시 중산간서로 1878-0   0.000000
# 99    한라산국립공원     제주 서귀포시 토평동 산15-1     제주 서귀포시 토평동 산15-1   0.000000
#
#             경도
# 0   126.564467
# 1   126.936427
# 2   126.318833
# 3   126.921357
# 4   126.555925
# ..         ...
# 95    0.000000
# ...

# %%
address_df.to_csv('jejusi op latitude and longitude.csv')
